# %% [markdown]
# # LetsGrowMore: Data Science
#
# # Task 5 : Develop A Neural Network That Can Read Handwriting
#
# # Name of Intern: Sachin Kumar Verma
#
# # Loading Packages and Data

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential 
from keras.layers.core import Dense, Activation
from keras.utils import np_utils

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
import matplotlib.pyplot as plt
n = 40  
plt.figure(figsize=(40, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
plt.close()

# %%
print("Previous x_train shape : {} \nPrevious y_train shape:{}".format(x_train.shape, y_train.shape))
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test=x_test.astype('float32')
x_train /=255
x_test /=255
classes = 10
y_train = np_utils.to_categorical(y_train, classes)
y_test = np_utils.to_categorical(y_test, classes)
print("New x_train shape: {} \nNew y_train shape:{}".format(x_train.shape, y_train.shape))
# Out:
# Previous x_train shape : (60000, 28, 28)
# Previous y_train shape:(60000,)
# New x_train shape: (60000, 784)
# New y_train shape:(60000, 10)

# %%
#Setting parameters
input_size = 784
batch_size = 200
hidden1 = 400
hidden2 = 20
epochs = 2

# %%
#Building Model
model = Sequential()     
model.add(Dense(hidden1, input_dim=input_size, activation='relu'))

model.add(Dense(hidden2, activation='relu'))
model.add(Dense(classes, activation='softmax')) 

model.compile(loss='categorical_crossentropy', 
metrics=['accuracy'], optimizer='sgd')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 400)               314000
#
#  dense_1 (Dense)             (None, 20)                8020
#
#  dense_2 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 322,230
# Trainable params: 322,230
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size=batch_size, epochs=100 , verbose=2 )
# Out:
# Epoch 1/100
# 300/300 - 3s - loss: 1.5741 - accuracy: 0.5721 - 3s/epoch - 10ms/step
# Epoch 2/100
# 300/300 - 2s - loss: 0.6951 - accuracy: 0.8422 - 2s/epoch - 8ms/step
# Epoch 3/100
# 300/300 - 2s - loss: 0.4783 - accuracy: 0.8759 - 2s/epoch - 8ms/step
# Epoch 4/100
# 300/300 - 2s - loss: 0.4023 - accuracy: 0.8898 - 2s/epoch - 8ms/step
# Epoch 5/100
# 300/300 - 2s - loss: 0.3612 - accuracy: 0.8985 - 2s/epoch - 8ms/step
# Epoch 6/100
# 300/300 - 2s - loss: 0.3339 - accuracy: 0.9059 - 2s/epoch - 8ms/step
# Epoch 7/100
# 300/300 - 2s - loss: 0.3135 - accuracy: 0.9108 - 2s/epoch - 8ms/step
# Epoch 8/100
# 300/300 - 2s - loss: 0.2970 - accuracy: 0.9153 - 2s/epoch - 8ms/step
# Epoch 9/100
# 300/300 - 2s - loss: 0.2829 - accuracy: 0.9194 - 2s/epoch - 8ms/step
# Epoch 10/100
# 300/300 - 2s - loss: 0.2709 - accuracy: 0.9225 - 2s/epoch - 7ms/step
# Epoch 11/100
# 300/300 - 2s - loss: 0.2605 - accuracy: 0.9261 - 2s/epoch - 8ms/step
# Epoch 12/100
# 300/300 - 2s - loss: 0.2509 - accuracy: 0.9287 - 2s/epoch - 7ms/step
# Epoch 13/100
# 300/300 - 2s - loss: 0.2420 - accuracy: 0.9310 - 2s/epoch - 7ms/step
# Epoch 14/100
# 300/300 - 2s - loss: 0.2340 - accuracy: 0.9334 - 2s/epoch - 7ms/step
# Epoch 15/100
# 300/300 - 2s - loss: 0.2268 - accuracy: 0.9352 - 2s/epoch - 8ms/step
# Epoch 16/100
# 300/300 - 2s - loss: 0.2196 - accuracy: 0.9379 - 2s/epoch - 8ms/step
# Epoch 17/100
# 300/300 - 2s - loss: 0.2132 - accuracy: 0.9397 - 2s/epoch - 7ms/step
# Epoch 18/100
# 300/300 - 2s - loss: 0.2070 - accuracy: 0.9418 - 2s/epoch - 7ms/step
# Epoch 19/100
# 300/300 - 2s - loss: 0.2011 - accuracy: 0.9431 - 2s/epoch - 8ms/step
# Epoch 20/100
# 300/300 - 2s - loss: 0.1956 - accuracy: 0.9450 - 2s/epoch - 7ms/step
# Epoch 21/100
# 300/300 - 2s - loss: 0.1905 - accuracy: 0.9465 - 2s/epoch - 7ms/step
# Epoch 22/100
# 300/300 - 2s - loss: 0.1855 - accuracy: 0.9478 - 2s/epoch - 7ms/step
# Epoch 23/100
# 300/300 - 2s - loss: 0.1809 - accuracy: 0.9491 - 2s/epoch - 7ms/step
# Epoch 24/100
# 300/300 - 2s - loss: 0.1764 - accuracy: 0.9501 - 2s/epoch - 6ms/step
# Epoch 25/100
# 300/300 - 2s - loss: 0.1721 - accuracy: 0.9516 - 2s/epoch - 6ms/step
# Epoch 26/100
# 300/300 - 2s - loss: 0.1680 - accuracy: 0.9531 - 2s/epoch - 7ms/step
# Epoch 27/100
# 300/300 - 2s - loss: 0.1640 - accuracy: 0.9542 - 2s/epoch - 8ms/step
# Epoch 28/100
# 300/300 - 2s - loss: 0.1604 - accuracy: 0.9548 - 2s/epoch - 7ms/step
# Epoch 29/100
# 300/300 - 2s - loss: 0.1567 - accuracy: 0.9560 - 2s/epoch - 7ms/step
# Epoch 30/100
# 300/300 - 2s - loss: 0.1531 - accuracy: 0.9567 - 2s/epoch - 7ms/step
# Epoch 31/100
# 300/300 - 2s - loss: 0.1499 - accuracy: 0.9577 - 2s/epoch - 7ms/step
# Epoch 32/100
# 300/300 - 2s - loss: 0.1466 - accuracy: 0.9591 - 2s/epoch - 7ms/step
# Epoch 33/100
# 300/300 - 2s - loss: 0.1435 - accuracy: 0.9598 - 2s/epoch - 7ms/step
# Epoch 34/100
# 300/300 - 2s - loss: 0.1405 - accuracy: 0.9607 - 2s/epoch - 7ms/step
# Epoch 35/100
# 300/300 - 2s - loss: 0.1378 - accuracy: 0.9612 - 2s/epoch - 8ms/step
# Epoch 36/100
# 300/300 - 2s - loss: 0.1350 - accuracy: 0.9623 - 2s/epoch - 7ms/step
# Epoch 37/100
# 300/300 - 2s - loss: 0.1325 - accuracy: 0.9628 - 2s/epoch - 7ms/step
# Epoch 38/100
# 300/300 - 2s - loss: 0.1299 - accuracy: 0.9637 - 2s/epoch - 7ms/step
# Epoch 39/100
# 300/300 - 2s - loss: 0.1276 - accuracy: 0.9644 - 2s/epoch - 7ms/step
# Epoch 40/100
# 300/300 - 2s - loss: 0.1251 - accuracy: 0.9653 - 2s/epoch - 7ms/step
# Epoch 41/100
# 300/300 - 2s - loss: 0.1228 - accuracy: 0.9654 - 2s/epoch - 7ms/step
# Epoch 42/100
# 300/300 - 2s - loss: 0.1207 - accuracy: 0.9662 - 2s/epoch - 7ms/step
# Epoch 43/100
# 300/300 - 2s - loss: 0.1184 - accuracy: 0.9670 - 2s/epoch - 7ms/step
# Epoch 44/100
# 300/300 - 2s - loss: 0.1163 - accuracy: 0.9674 - 2s/epoch - 7ms/step
# Epoch 45/100
# 300/300 - 2s - loss: 0.1144 - accuracy: 0.9680 - 2s/epoch - 7ms/step
# Epoch 46/100
# 300/300 - 2s - loss: 0.1123 - accuracy: 0.9687 - 2s/epoch - 7ms/step
# Epoch 47/100
# 300/300 - 2s - loss: 0.1105 - accuracy: 0.9692 - 2s/epoch - 7ms/step
# Epoch 48/100
# 300/300 - 2s - loss: 0.1086 - accuracy: 0.9696 - 2s/epoch - 7ms/step
# Epoch 49/100
# 300/300 - 2s - loss: 0.1069 - accuracy: 0.9702 - 2s/epoch - 7ms/step
# Epoch 50/100
# 300/300 - 2s - loss: 0.1051 - accuracy: 0.9707 - 2s/epoch - 7ms/step
# Epoch 51/100
# 300/300 - 2s - loss: 0.1033 - accuracy: 0.9713 - 2s/epoch - 7ms/step
# Epoch 52/100
# 300/300 - 2s - loss: 0.1018 - accuracy: 0.9717 - 2s/epoch - 7ms/step
# Epoch 53/100
# 300/300 - 2s - loss: 0.1001 - accuracy: 0.9721 - 2s/epoch - 7ms/step
# Epoch 54/100
# 300/300 - 2s - loss: 0.0984 - accuracy: 0.9727 - 2s/epoch - 7ms/step
# Epoch 55/100
# 300/300 - 2s - loss: 0.0968 - accuracy: 0.9732 - 2s/epoch - 7ms/step
# Epoch 56/100
# 300/300 - 2s - loss: 0.0954 - accuracy: 0.9734 - 2s/epoch - 7ms/step
# Epoch 57/100
# 300/300 - 2s - loss: 0.0939 - accuracy: 0.9742 - 2s/epoch - 7ms/step
# Epoch 58/100
# 300/300 - 2s - loss: 0.0925 - accuracy: 0.9745 - 2s/epoch - 8ms/step
# Epoch 59/100
# 300/300 - 2s - loss: 0.0910 - accuracy: 0.9747 - 2s/epoch - 7ms/step
# Epoch 60/100
# 300/300 - 2s - loss: 0.0896 - accuracy: 0.9753 - 2s/epoch - 7ms/step
# Epoch 61/100
# 300/300 - 2s - loss: 0.0884 - accuracy: 0.9755 - 2s/epoch - 7ms/step
# Epoch 62/100
# 300/300 - 2s - loss: 0.0870 - accuracy: 0.9759 - 2s/epoch - 7ms/step
# Epoch 63/100
# 300/300 - 2s - loss: 0.0858 - accuracy: 0.9763 - 2s/epoch - 7ms/step
# Epoch 64/100
# 300/300 - 2s - loss: 0.0845 - accuracy: 0.9766 - 2s/epoch - 7ms/step
# Epoch 65/100
# 300/300 - 2s - loss: 0.0832 - accuracy: 0.9770 - 2s/epoch - 7ms/step
# Epoch 66/100
# 300/300 - 2s - loss: 0.0821 - accuracy: 0.9779 - 2s/epoch - 8ms/step
# Epoch 67/100
# 300/300 - 2s - loss: 0.0810 - accuracy: 0.9778 - 2s/epoch - 8ms/step
# Epoch 68/100
# 300/300 - 2s - loss: 0.0798 - accuracy: 0.9780 - 2s/epoch - 8ms/step
# Epoch 69/100
# 300/300 - 2s - loss: 0.0786 - accuracy: 0.9782 - 2s/epoch - 8ms/step
# Epoch 70/100
# 300/300 - 2s - loss: 0.0775 - accuracy: 0.9786 - 2s/epoch - 8ms/step
# Epoch 71/100
# 300/300 - 2s - loss: 0.0764 - accuracy: 0.9788 - 2s/epoch - 8ms/step
# Epoch 72/100
# 300/300 - 2s - loss: 0.0754 - accuracy: 0.9791 - 2s/epoch - 8ms/step
# Epoch 73/100
# 300/300 - 2s - loss: 0.0743 - accuracy: 0.9794 - 2s/epoch - 8ms/step
# Epoch 74/100
# 300/300 - 2s - loss: 0.0733 - accuracy: 0.9798 - 2s/epoch - 8ms/step
# Epoch 75/100
# 300/300 - 2s - loss: 0.0723 - accuracy: 0.9800 - 2s/epoch - 8ms/step
# Epoch 76/100
# 300/300 - 2s - loss: 0.0714 - accuracy: 0.9805 - 2s/epoch - 8ms/step
# Epoch 77/100
# 300/300 - 2s - loss: 0.0703 - accuracy: 0.9804 - 2s/epoch - 8ms/step
# Epoch 78/100
# 300/300 - 2s - loss: 0.0694 - accuracy: 0.9809 - 2s/epoch - 8ms/step
# Epoch 79/100
# 300/300 - 2s - loss: 0.0685 - accuracy: 0.9811 - 2s/epoch - 8ms/step
# Epoch 80/100
# 300/300 - 2s - loss: 0.0676 - accuracy: 0.9814 - 2s/epoch - 8ms/step
# Epoch 81/100
# 300/300 - 2s - loss: 0.0666 - accuracy: 0.9818 - 2s/epoch - 8ms/step
# Epoch 82/100
# 300/300 - 2s - loss: 0.0658 - accuracy: 0.9818 - 2s/epoch - 8ms/step
# Epoch 83/100
# 300/300 - 2s - loss: 0.0649 - accuracy: 0.9821 - 2s/epoch - 8ms/step
# Epoch 84/100
# 300/300 - 2s - loss: 0.0640 - accuracy: 0.9825 - 2s/epoch - 8ms/step
# Epoch 85/100
# 300/300 - 2s - loss: 0.0633 - accuracy: 0.9827 - 2s/epoch - 7ms/step
# Epoch 86/100
# 300/300 - 2s - loss: 0.0624 - accuracy: 0.9831 - 2s/epoch - 6ms/step
# Epoch 87/100
# 300/300 - 2s - loss: 0.0617 - accuracy: 0.9832 - 2s/epoch - 5ms/step
# Epoch 88/100
# 300/300 - 2s - loss: 0.0609 - accuracy: 0.9836 - 2s/epoch - 6ms/step
# Epoch 89/100
# 300/300 - 2s - loss: 0.0600 - accuracy: 0.9836 - 2s/epoch - 6ms/step
# Epoch 90/100
# 300/300 - 2s - loss: 0.0594 - accuracy: 0.9840 - 2s/epoch - 7ms/step
# Epoch 91/100
# 300/300 - 2s - loss: 0.0586 - accuracy: 0.9840 - 2s/epoch - 7ms/step
# Epoch 92/100
# 300/300 - 2s - loss: 0.0578 - accuracy: 0.9843 - 2s/epoch - 8ms/step
# Epoch 93/100
# 300/300 - 2s - loss: 0.0570 - accuracy: 0.9848 - 2s/epoch - 8ms/step
# Epoch 94/100
# 300/300 - 2s - loss: 0.0563 - accuracy: 0.9850 - 2s/epoch - 8ms/step
# Epoch 95/100
# 300/300 - 2s - loss: 0.0557 - accuracy: 0.9854 - 2s/epoch - 8ms/step
# Epoch 96/100
# 300/300 - 2s - loss: 0.0549 - accuracy: 0.9854 - 2s/epoch - 8ms/step
# Epoch 97/100
# 300/300 - 2s - loss: 0.0543 - accuracy: 0.9855 - 2s/epoch - 8ms/step
# Epoch 98/100
# 300/300 - 2s - loss: 0.0536 - accuracy: 0.9859 - 2s/epoch - 8ms/step
# Epoch 99/100
# 300/300 - 2s - loss: 0.0529 - accuracy: 0.9859 - 2s/epoch - 8ms/step
# Epoch 100/100
# 300/300 - 2s - loss: 0.0523 - accuracy: 0.9864 - 2s/epoch - 8ms/step

# %%
score = model.evaluate(x_test, y_test, verbose=1)
print('\n''Test accuracy:', score[1])
mask = range(0,40)
x_valid = x_test[mask]
predict_y=model.predict(x_valid) 
classes_y=np.argmax(predict_y,axis=1)
print(classes_y)

# display original
plt.figure(figsize=(40, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_valid[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
plt.close()
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0800 - accuracy: 0.9755
#
# Test accuracy: 0.9754999876022339
# 2/2 [==============================] - 0s 5ms/step
# [7 2 1 0 4 1 4 9 6 9 0 6 9 0 1 5 9 7 3 4 9 6 6 5 4 0 7 4 0 1 3 1 3 4 7 2 7
#  1 2 1]

# %% [markdown]
# ## Conclusion :
#
# ## Accuracy is : 97.43 %
#
# ## Thank You
